# %%
import pandas as pd
pd.set_option('display.mpl_style', 'default')

# %%
ls
# Out:
# Chevere/     Histogramer.ipynb  numpy100.txt~  Scala Stuff/  WHO.csv
# Code/        JavaSocket/        numpyEx/       Test/
# C-Projects/  numpy100.txt       run.py*        Whisper/

# %%
dataframe =  pd.read_csv("training.csv")

# %%
dataframe
# Out:
#         EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 0        100000       138.470                       51.655        97.827
# 1        100001       160.937                       68.768       103.235
# 2        100002      -999.000                      162.172       125.953
# 3        100003       143.905                       81.417        80.943
# 4        100004       175.864                       16.915       134.805
# 5        100005        89.744                       13.550        59.149
# 6        100006       148.754                       28.862       107.782
# 7        100007       154.916                       10.418        94.714
# 8        100008       105.594                       50.559       100.989
# 9        100009       128.053                       88.941        69.272
# 10       100010      -999.000                       86.240        79.692
# 11       100011       114.744                       10.286        75.712
# ...

# %%
condition  =  dataframe['Label'] == 'b'

# %%
data = dataframe[condition]

# %%
data
# Out:
#         EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 1        100001       160.937                       68.768       103.235
# 2        100002      -999.000                      162.172       125.953
# 3        100003       143.905                       81.417        80.943
# 4        100004       175.864                       16.915       134.805
# 5        100005        89.744                       13.550        59.149
# 8        100008       105.594                       50.559       100.989
# 10       100010      -999.000                       86.240        79.692
# 11       100011       114.744                       10.286        75.712
# 12       100012       145.297                       64.234       103.565
# 13       100013        82.488                       31.663        64.128
# 14       100014      -999.000                      109.412        14.398
# 16       100016       114.256                        4.351        67.963
# ...

# %%
data = data[data['PRI_jet_num']== 1]

# %%
data
# Out:
#         EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 1        100001       160.937                       68.768       103.235
# 2        100002      -999.000                      162.172       125.953
# 12       100012       145.297                       64.234       103.565
# 16       100016       114.256                        4.351        67.963
# 30       100030      -999.000                       91.316        51.771
# 34       100034       156.894                       39.256       122.894
# 35       100035        72.712                       20.762        50.255
# 50       100050       219.057                       72.461       124.835
# 62       100062       139.394                       71.611        78.711
# 64       100064        92.696                       51.669        68.835
# 65       100065        83.081                       63.334        60.631
# 72       100072        96.906                       71.751        74.602
# ...

# %%
dataframe["PRI_jet_leading_pt"].hist(by=dataframe["PRI_jet_num"], figsize=(15,15), sharex=True, sharey=True)
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x6bd02910>,
# ...
#         <matplotlib.axes.AxesSubplot object at 0x57659d90>]], dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
a = [1,2]

# %%
condition = dataframe["PRI_jet_num"].isin(a)

# %%
data = dataframe[condition]

# %%
data["PRI_jet_leading_pt"].hist(by=data["PRI_jet_num"], figsize=(15,15), sharex=True, sharey=True)
# Out:
# array([<matplotlib.axes.AxesSubplot object at 0x56dfec90>,
#        <matplotlib.axes.AxesSubplot object at 0x543fbe10>], dtype=object)

# %%
lel = data['PRI_jet_num'].value_counts().keys()[:1]

# %%
lel
# Out:
# Int64Index([1], dtype='int64')

# %%
i=4

# %%
if i==4 : i=5

# %%
i
# Out:
# 5
